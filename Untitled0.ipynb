# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/GuyTevet/motion-diffusion-model.git
# %cd motion-diffusion-model
# !pip install -r ../requirements.txt
#Patching Chumpy (The "Life Support" for Python 3.12)
import inspect
if not hasattr(inspect, 'getargspec'):
    inspect.getargspec = inspect.getfullargspec

# %%
# !mkdir -p dataset/HumanML3D body_models/smpl glove
# !gdown --fuzzy "https://drive.google.com/file/d/1cmXKUT31pqd7_XpJAiWEo1K81TMYHA5n/view?usp=sharing" -O glove/glove.zip
# !unzip -q glove/glove.zip -d glove/
# !wget https://huggingface.co/vpetushkov/smpl-models/resolve/main/SMPL_NEUTRAL.pkl -O body_models/smpl/SMPL_NEUTRAL.pkl
# !wget https://huggingface.co/Kleinhe/CAMD/resolve/40fb698fb2bd196f9ede115b2cbacd115c434a75/body_models/smpl/J_regressor_extra.npy -O body_models/smpl/J_regressor_extra.npy

# NOTE: Move your preprocessed HumanML3D files into dataset/HumanML3D/ here

# %%
import os
os.environ["WANDB_ENTITY"] = "your_user_name"
os.environ["WANDB_PROJECT"] = "motion-diffusion-cmu"

# !python -m train.train_mdm \
    --save_dir ./save/my_trained_model \
    --dataset humanml \
    --batch_size 32 \
    --layers 8 \
    --diffusion_steps 1000 \
    --log_interval 100 \
    --save_interval 5000
